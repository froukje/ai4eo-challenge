# %% [markdown]
# # Setup

# %%
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Read Data

# %%
path = 'data'
h5_valid = h5py.File(os.path.join(path, 'valid.h5'), 'r')
h5_pred = h5py.File(os.path.join(path, 'best_hr_predictions.h5'), 'r')

# %%
for key in h5_lr.keys():
    print(key)
# Out:
# X
# y

# %%
lr_valid = h5_valid['X'][:]
hr_valid = h5_valid['y'][:]
hr_pred = h5_pred['y_pred'][:]

# %%
print(f'low res shape: {lr_valid.shape}')
print(f'high res shape: {hr_valid.shape}')
print(f'high res pred shape: {hr_pred.shape}')
# Out:
# low res shape: (25, 96, 96, 3)
# high res shape: (25, 384, 384, 3)
# high res pred shape: (25, 3, 384, 384)

# %%
hr_valid[idx].shape
# Out:
# (384, 384, 3)

# %%
hr_valid[idx].shape
# Out:
# (384, 384, 3)

# %%
idx = np.random.randint(0, 25)
img_lr_valid = Image.fromarray(lr_valid[idx], 'RGB')
img_hr_valid = Image.fromarray(hr_valid[idx], 'RGB')
tmp = np.swapaxes(hr_pred[idx], 0, 2)
img = np.swapaxes(tmp, 0, 1)
img_hr_pred = Image.fromarray(img, 'RGB')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 10))
axes[0].imshow(img_lr_valid)
axes[0].axis('off')
axes[1].imshow(img_hr_valid)
axes[1].axis('off')
axes[2].imshow(img_hr_pred)
axes[2].axis('off')
plt.show()
